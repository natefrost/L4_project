# %%
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Dataset/Pretraining stuff

# %%
labels = np.load('/content/drive/My Drive/Colab Notebooks/labels.npy')
audios = np.load('/content/drive/My Drive/Colab Notebooks/audios.npy')

from keras.utils import np_utils
from sklearn.preprocessing import LabelEncoder, label_binarize
from sklearn.model_selection import train_test_split

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import wave
import pylab
from pathlib import Path
import scipy
from scipy import signal, fft
from scipy.io import wavfile
from sklearn.metrics import confusion_matrix
import itertools
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal
import cv2
import time
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, label_binarize
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import RandomizedSearchCV
from keras.wrappers.scikit_learn import KerasClassifier
from keras.regularizers import l1

# %%
# https://towardsdatascience.com/understanding-audio-data-fourier-transform-fft-spectrogram-and-speech-recognition-a4072d228520

def spectrogram(samples, sample_rate, stride_ms = 10.0, 
                          window_ms = 20.0, max_freq = None, eps = 1e-14):

    stride_size = int(0.001 * sample_rate * stride_ms)
    window_size = int(0.001 * sample_rate * window_ms)

    # Extract strided windows
    truncate_size = (len(samples) - window_size) % stride_size
    samples = samples[:len(samples) - truncate_size]
    nshape = (window_size, (len(samples) - window_size) // stride_size + 1)
    nstrides = (samples.strides[0], samples.strides[0] * stride_size)
    windows = np.lib.stride_tricks.as_strided(samples, 
                                          shape = nshape, strides = nstrides)
    
    assert np.all(windows[:, 1] == samples[stride_size:(stride_size + window_size)])

    # Window weighting, squared Fast Fourier Transform (fft), scaling
    weighting = np.hanning(window_size)[:, None]
    
    fft = np.fft.rfft(windows * weighting, axis=0)
    fft = np.absolute(fft)
    fft = fft**2
    
    scale = np.sum(weighting**2) * sample_rate
    fft[1:-1, :] *= (2.0 / scale)
    fft[(0, -1), :] /= scale
    
    # Prepare fft frequency list
    freqs = float(sample_rate) / window_size * np.arange(fft.shape[0])
    
    # Compute spectrogram feature
    ind = np.where(freqs <= max_freq)[0][-1] + 1
    specgram = np.log(fft[:ind, :] + eps)
    return specgram

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal
import cv2
sr = 22050
# A2S = Audio sequence to spectrogram

# Dont convert to 64x64

def a2s(audio_sequence, sampling_rate=sr):
    cut_audio = audio_sequence#[audio_sequence!=0]

    spec = spectrogram(cut_audio, sample_rate = sampling_rate, max_freq = 11025)
    return spec

# %%
# Uncut audios
import time

start = time.time()
specs = np.apply_along_axis(a2s, 1, audios)

print(time.time() - start)
# Out:
# 18.046889066696167

# %%
specs.shape
from keras.callbacks import History

# %%
plt.imshow(specs[200])

# %%
mask = np.logical_or(labels=='other', labels=='X')

labels = labels[~mask]
specs = specs[~mask]

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, label_binarize

np.sum(label_binarize(labels, classes=['angry', 'happy', 'sad', 'neutral']), axis=0)
# Out:
# array([284, 224, 186, 524])

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, label_binarize

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(specs, labels, test_size=0.25)

y_bin = label_binarize(y_train, classes=['angry', 'happy', 'sad', 'neutral',])
y_bin2 = label_binarize(y_test, classes=['angry', 'happy', 'sad', 'neutral',])

# %%
def plothist(hist):
      plt.plot(hist.history['loss'])
      plt.plot(hist.history['val_loss'])
      plt.title('Model Loss')
      plt.ylabel('Loss')
      plt.xlabel('Epoch')
      plt.legend(['Train', 'Validation'], loc='upper right')
      plt.show()

      plt.plot(hist.history['accuracy'])
      plt.plot(hist.history['val_accuracy'])
      plt.title('Model Accuracy')
      plt.ylabel('Accuracy')
      plt.xlabel('Epoch')
      plt.legend(['Train', 'Validation'], loc='upper right')
      plt.show()

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from keras.optimizers import Adam

# %%
def create_model(num_filters_1, num_filters_2, dense_units, dropout_rate, l1_reg):
    model = Sequential()

    model.add(Conv2D(num_filters_1, (3, 3), activation='relu', input_shape=(221, 1537, 1), kernel_regularizer=l1(l1_reg)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(num_filters_2, (3, 3), activation='relu', kernel_regularizer=l1(l1_reg)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(dense_units, activation='relu', kernel_regularizer=l1(l1_reg)))
    model.add(Dropout(dropout_rate))
    model.add(Dense(4, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    return model

# %%
np.sum(y_bin, axis=0)
# Out:
# array([204, 161, 132, 416])

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=720)

# %%
y_train_val = label_binarize(y_train, classes=['angry', 'happy', 'sad', 'neutral',])

# %% [markdown]
# # Data Aug

# %%
np.sum(y_train_val, axis=0)
# Out:
# array([186, 119, 107, 318])

# %%
from imblearn.over_sampling import RandomOverSampler

oversample = RandomOverSampler(sampling_strategy={'angry': 200, 'happy': 200, 'sad': 200})

# %%
X_train_reshaped = np.reshape(X_train, (X_train.shape[0], -1))

# %%
X_train_aug, y_train_aug = oversample.fit_resample(X_train_reshaped, y_train)

# %%
specs_aug = X_train_aug.reshape(X_train_aug.shape[0], 221, 1537)

# %%
y_bin_aug = label_binarize(y_train_aug, classes=['angry', 'happy', 'sad', 'neutral',])

# %%
np.sum(y_bin_aug, axis=0)
# Out:
# array([200, 200, 200, 318])

# %%
plt.imshow(specs_aug[900])

# %%
y_val_bin = label_binarize(y_val, classes=['angry', 'happy', 'sad', 'neutral',])

# %% [markdown]
# # Training aug

# %%
history = History()
model = create_model(16, 16, 256, 0.2, 0.001)
model.fit(X_train, y_bin, epochs=25, batch_size=32, verbose=1, shuffle=True,validation_split=0.2, callbacks=[history])
# Out:
# Epoch 1/25
# 24/24 [==============================] - 15s 202ms/step - loss: 622.0302 - accuracy: 0.2687 - val_loss: 178.6600 - val_accuracy: 0.2094
# Epoch 2/25
# 24/24 [==============================] - 3s 126ms/step - loss: 167.3264 - accuracy: 0.3408 - val_loss: 151.4351 - val_accuracy: 0.4503
# Epoch 3/25
# 24/24 [==============================] - 3s 127ms/step - loss: 136.9185 - accuracy: 0.4666 - val_loss: 121.4247 - val_accuracy: 0.4398
# Epoch 4/25
# 24/24 [==============================] - 3s 128ms/step - loss: 110.0866 - accuracy: 0.5177 - val_loss: 98.4873 - val_accuracy: 0.4660
# Epoch 5/25
# 24/24 [==============================] - 3s 127ms/step - loss: 89.2053 - accuracy: 0.5177 - val_loss: 80.2493 - val_accuracy: 0.4921
# Epoch 6/25
# 24/24 [==============================] - 3s 129ms/step - loss: 72.8620 - accuracy: 0.5439 - val_loss: 65.7781 - val_accuracy: 0.4712
# Epoch 7/25
# 24/24 [==============================] - 3s 127ms/step - loss: 59.7253 - accuracy: 0.5609 - val_loss: 54.1961 - val_accuracy: 0.4817
# Epoch 8/25
# 24/24 [==============================] - 3s 126ms/step - loss: 49.1419 - accuracy: 0.5609 - val_loss: 44.1382 - val_accuracy: 0.4921
# Epoch 9/25
# 24/24 [==============================] - 3s 130ms/step - loss: 40.7213 - accuracy: 0.5780 - val_loss: 37.4054 - val_accuracy: 0.5026
# Epoch 10/25
# 24/24 [==============================] - 3s 130ms/step - loss: 33.8664 - accuracy: 0.6199 - val_loss: 31.5446 - val_accuracy: 0.4503
# Epoch 11/25
# 24/24 [==============================] - 3s 128ms/step - loss: 28.3640 - accuracy: 0.6186 - val_loss: 26.2553 - val_accuracy: 0.4712
# Epoch 12/25
# 24/24 [==============================] - 3s 128ms/step - loss: 24.0333 - accuracy: 0.6370 - val_loss: 22.4357 - val_accuracy: 0.4974
# Epoch 13/25
# 24/24 [==============================] - 3s 131ms/step - loss: 20.4676 - accuracy: 0.6723 - val_loss: 19.7483 - val_accuracy: 0.4817
# Epoch 14/25
# 24/24 [==============================] - 3s 128ms/step - loss: 17.7228 - accuracy: 0.6710 - val_loss: 16.9097 - val_accuracy: 0.4817
# Epoch 15/25
# 24/24 [==============================] - 3s 129ms/step - loss: 15.2984 - accuracy: 0.7012 - val_loss: 15.4382 - val_accuracy: 0.4817
# Epoch 16/25
# 24/24 [==============================] - 3s 130ms/step - loss: 13.8333 - accuracy: 0.7090 - val_loss: 14.0108 - val_accuracy: 0.5026
# Epoch 17/25
# 24/24 [==============================] - 3s 130ms/step - loss: 12.4416 - accuracy: 0.7706 - val_loss: 12.9565 - val_accuracy: 0.3508
# Epoch 18/25
# 24/24 [==============================] - 3s 128ms/step - loss: 11.4965 - accuracy: 0.7575 - val_loss: 11.7733 - val_accuracy: 0.4764
# Epoch 19/25
# 24/24 [==============================] - 3s 130ms/step - loss: 10.4540 - accuracy: 0.8414 - val_loss: 11.2883 - val_accuracy: 0.4660
# Epoch 20/25
# 24/24 [==============================] - 3s 130ms/step - loss: 9.7096 - accuracy: 0.8244 - val_loss: 11.0620 - val_accuracy: 0.4660
# Epoch 21/25
# 24/24 [==============================] - 3s 137ms/step - loss: 9.5414 - accuracy: 0.8309 - val_loss: 10.9325 - val_accuracy: 0.4450
# Epoch 22/25
# 24/24 [==============================] - 3s 130ms/step - loss: 9.3873 - accuracy: 0.8336 - val_loss: 10.2866 - val_accuracy: 0.4712
# Epoch 23/25
# 24/24 [==============================] - 3s 130ms/step - loss: 8.9921 - accuracy: 0.8742 - val_loss: 10.1299 - val_accuracy: 0.4450
# Epoch 24/25
# 24/24 [==============================] - 3s 132ms/step - loss: 8.5367 - accuracy: 0.9069 - val_loss: 10.0107 - val_accuracy: 0.4398
# Epoch 25/25
# 24/24 [==============================] - 3s 132ms/step - loss: 8.3782 - accuracy: 0.9083 - val_loss: 10.0717 - val_accuracy: 0.4241

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
history2 = History()
model = create_model(64, 64, 128, 0.2, 0.001)
model.fit(X_train, y_bin, epochs=25, batch_size=32, verbose=1, shuffle=True,validation_split=0.2, callbacks=[history2])
# Out:
# Epoch 1/25
# 24/24 [==============================] - 22s 574ms/step - loss: 332.7532 - accuracy: 0.3159 - val_loss: 220.0052 - val_accuracy: 0.2042
# Epoch 2/25
# 24/24 [==============================] - 10s 413ms/step - loss: 192.5411 - accuracy: 0.4181 - val_loss: 162.3851 - val_accuracy: 0.2199
# Epoch 3/25
# 24/24 [==============================] - 10s 413ms/step - loss: 138.5751 - accuracy: 0.4692 - val_loss: 115.7187 - val_accuracy: 0.4084
# Epoch 4/25
# 24/24 [==============================] - 10s 411ms/step - loss: 104.2917 - accuracy: 0.5059 - val_loss: 92.7813 - val_accuracy: 0.4398
# Epoch 5/25
# 24/24 [==============================] - 10s 420ms/step - loss: 83.6979 - accuracy: 0.5046 - val_loss: 73.9635 - val_accuracy: 0.4293
# Epoch 6/25
# 24/24 [==============================] - 10s 419ms/step - loss: 69.0759 - accuracy: 0.5426 - val_loss: 61.0726 - val_accuracy: 0.4450
# Epoch 7/25
# 24/24 [==============================] - 10s 417ms/step - loss: 60.1385 - accuracy: 0.5203 - val_loss: 58.4236 - val_accuracy: 0.4398
# Epoch 8/25
# 24/24 [==============================] - 10s 416ms/step - loss: 58.3874 - accuracy: 0.5439 - val_loss: 56.8229 - val_accuracy: 0.4346
# Epoch 9/25
# 24/24 [==============================] - 10s 421ms/step - loss: 55.3868 - accuracy: 0.5845 - val_loss: 54.0950 - val_accuracy: 0.4398
# Epoch 10/25
# 24/24 [==============================] - 10s 433ms/step - loss: 52.9828 - accuracy: 0.6461 - val_loss: 47.8578 - val_accuracy: 0.4660
# Epoch 11/25
# 24/24 [==============================] - 10s 429ms/step - loss: 47.5707 - accuracy: 0.6330 - val_loss: 43.2520 - val_accuracy: 0.4241
# Epoch 12/25
# 24/24 [==============================] - 10s 419ms/step - loss: 41.2464 - accuracy: 0.6632 - val_loss: 39.8736 - val_accuracy: 0.4817
# Epoch 13/25
# 24/24 [==============================] - 10s 424ms/step - loss: 37.1420 - accuracy: 0.6920 - val_loss: 33.6427 - val_accuracy: 0.4450
# Epoch 14/25
# 24/24 [==============================] - 10s 417ms/step - loss: 30.1774 - accuracy: 0.7104 - val_loss: 28.8513 - val_accuracy: 0.4817
# Epoch 15/25
# 24/24 [==============================] - 10s 426ms/step - loss: 25.3545 - accuracy: 0.7759 - val_loss: 23.8889 - val_accuracy: 0.4031
# Epoch 16/25
# 24/24 [==============================] - 10s 422ms/step - loss: 36.2469 - accuracy: 0.6343 - val_loss: 38.1990 - val_accuracy: 0.3822
# Epoch 17/25
# 24/24 [==============================] - 10s 415ms/step - loss: 33.9884 - accuracy: 0.7326 - val_loss: 30.6293 - val_accuracy: 0.4450
# Epoch 18/25
# 24/24 [==============================] - 10s 410ms/step - loss: 27.3035 - accuracy: 0.8021 - val_loss: 25.6600 - val_accuracy: 0.4031
# Epoch 19/25
# 24/24 [==============================] - 10s 423ms/step - loss: 23.0898 - accuracy: 0.8244 - val_loss: 22.6871 - val_accuracy: 0.3979
# Epoch 20/25
# 24/24 [==============================] - 10s 419ms/step - loss: 20.6238 - accuracy: 0.8637 - val_loss: 21.0353 - val_accuracy: 0.4188
# Epoch 21/25
# 24/24 [==============================] - 10s 429ms/step - loss: 19.4014 - accuracy: 0.8585 - val_loss: 20.3610 - val_accuracy: 0.4241
# Epoch 22/25
# 24/24 [==============================] - 10s 419ms/step - loss: 18.6267 - accuracy: 0.8794 - val_loss: 19.5987 - val_accuracy: 0.4293
# Epoch 23/25
# 24/24 [==============================] - 10s 423ms/step - loss: 18.0859 - accuracy: 0.8820 - val_loss: 19.2175 - val_accuracy: 0.3927
# Epoch 24/25
# 24/24 [==============================] - 10s 414ms/step - loss: 17.7370 - accuracy: 0.9004 - val_loss: 19.3936 - val_accuracy: 0.4293
# Epoch 25/25
# 24/24 [==============================] - 10s 418ms/step - loss: 22.0740 - accuracy: 0.8257 - val_loss: 22.1644 - val_accuracy: 0.4136

# %%
plothist(history2)

# %%
history3 = History()
model = create_model(16, 32, 512, 0.15, 0.0001)
model.fit(X_train, y_bin, epochs=20, batch_size=32, verbose=1, shuffle=True,validation_split=0.2, callbacks=[history3])
# Out:
# Epoch 1/20
# 24/24 [==============================] - 14s 308ms/step - loss: 377.1173 - accuracy: 0.2988 - val_loss: 82.0726 - val_accuracy: 0.4555
# Epoch 2/20
# 24/24 [==============================] - 6s 229ms/step - loss: 80.5899 - accuracy: 0.5020 - val_loss: 76.8335 - val_accuracy: 0.4031
# Epoch 3/20
# 24/24 [==============================] - 6s 232ms/step - loss: 72.5228 - accuracy: 0.5898 - val_loss: 68.2450 - val_accuracy: 0.4136
# Epoch 4/20
# 24/24 [==============================] - 6s 230ms/step - loss: 63.6216 - accuracy: 0.7248 - val_loss: 59.9799 - val_accuracy: 0.4869
# Epoch 5/20
# 24/24 [==============================] - 6s 230ms/step - loss: 55.6877 - accuracy: 0.8034 - val_loss: 53.2798 - val_accuracy: 0.4660
# Epoch 6/20
# 24/24 [==============================] - 6s 231ms/step - loss: 49.0281 - accuracy: 0.9122 - val_loss: 47.0958 - val_accuracy: 0.4869
# Epoch 7/20
# 24/24 [==============================] - 6s 230ms/step - loss: 43.1887 - accuracy: 0.9083 - val_loss: 41.9733 - val_accuracy: 0.4346
# Epoch 8/20
# 24/24 [==============================] - 6s 232ms/step - loss: 38.1951 - accuracy: 0.9450 - val_loss: 37.1694 - val_accuracy: 0.4764
# Epoch 9/20
# 24/24 [==============================] - 6s 233ms/step - loss: 33.5440 - accuracy: 0.9712 - val_loss: 33.0473 - val_accuracy: 0.4450
# Epoch 10/20
# 24/24 [==============================] - 6s 236ms/step - loss: 29.6987 - accuracy: 0.9751 - val_loss: 29.8054 - val_accuracy: 0.4398
# Epoch 11/20
# 24/24 [==============================] - 6s 231ms/step - loss: 26.5779 - accuracy: 0.9633 - val_loss: 26.7028 - val_accuracy: 0.4398
# Epoch 12/20
# 24/24 [==============================] - 6s 233ms/step - loss: 23.7140 - accuracy: 0.9751 - val_loss: 24.0454 - val_accuracy: 0.4398
# Epoch 13/20
# 24/24 [==============================] - 6s 232ms/step - loss: 21.2685 - accuracy: 0.9554 - val_loss: 22.1278 - val_accuracy: 0.4293
# Epoch 14/20
# 24/24 [==============================] - 6s 230ms/step - loss: 19.3264 - accuracy: 0.9541 - val_loss: 20.2820 - val_accuracy: 0.3665
# Epoch 15/20
# 24/24 [==============================] - 6s 233ms/step - loss: 17.3130 - accuracy: 0.9699 - val_loss: 18.5357 - val_accuracy: 0.3979
# Epoch 16/20
# 24/24 [==============================] - 6s 233ms/step - loss: 15.6068 - accuracy: 0.9843 - val_loss: 16.6387 - val_accuracy: 0.4503
# Epoch 17/20
# 24/24 [==============================] - 6s 236ms/step - loss: 14.1047 - accuracy: 0.9895 - val_loss: 15.3564 - val_accuracy: 0.4188
# Epoch 18/20
# 24/24 [==============================] - 6s 233ms/step - loss: 12.7333 - accuracy: 0.9856 - val_loss: 14.3046 - val_accuracy: 0.4503
# Epoch 19/20
# 24/24 [==============================] - 6s 234ms/step - loss: 11.7334 - accuracy: 0.9581 - val_loss: 13.1883 - val_accuracy: 0.3979
# Epoch 20/20
# 24/24 [==============================] - 6s 233ms/step - loss: 10.8562 - accuracy: 0.9646 - val_loss: 12.8260 - val_accuracy: 0.3665

# %%
plothist(history3)

# %%
history4 = History()
model = create_model(16, 16, 512, 0.2, 0.005)
model.fit(X_train, y_bin, epochs=20, batch_size=32, verbose=1, shuffle=True,validation_split=0.2, callbacks=[history4])
plothist(history4)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 11s 230ms/step - loss: 1099.6938 - accuracy: 0.3080 - val_loss: 560.0541 - val_accuracy: 0.4084
# Epoch 2/20
# 24/24 [==============================] - 4s 156ms/step - loss: 424.0487 - accuracy: 0.4063 - val_loss: 310.9249 - val_accuracy: 0.4398
# Epoch 3/20
# 24/24 [==============================] - 4s 156ms/step - loss: 247.8365 - accuracy: 0.4417 - val_loss: 188.6025 - val_accuracy: 0.4607
# Epoch 4/20
# 24/24 [==============================] - 4s 160ms/step - loss: 167.3875 - accuracy: 0.4430 - val_loss: 145.6611 - val_accuracy: 0.4555
# Epoch 5/20
# 24/24 [==============================] - 4s 156ms/step - loss: 132.1104 - accuracy: 0.4299 - val_loss: 124.6256 - val_accuracy: 0.4555
# Epoch 6/20
# 24/24 [==============================] - 4s 157ms/step - loss: 114.7922 - accuracy: 0.4102 - val_loss: 109.5098 - val_accuracy: 0.4241
# Epoch 7/20
# 24/24 [==============================] - 4s 163ms/step - loss: 106.6402 - accuracy: 0.4246 - val_loss: 103.4970 - val_accuracy: 0.4555
# Epoch 8/20
# 24/24 [==============================] - 4s 159ms/step - loss: 100.0213 - accuracy: 0.4377 - val_loss: 92.2316 - val_accuracy: 0.4136
# Epoch 9/20
# 24/24 [==============================] - 4s 158ms/step - loss: 96.0885 - accuracy: 0.4325 - val_loss: 97.1326 - val_accuracy: 0.4398
# Epoch 10/20
# 24/24 [==============================] - 4s 159ms/step - loss: 95.1311 - accuracy: 0.4456 - val_loss: 95.6518 - val_accuracy: 0.4607
# Epoch 11/20
# 24/24 [==============================] - 4s 159ms/step - loss: 93.9103 - accuracy: 0.4194 - val_loss: 95.1160 - val_accuracy: 0.4503
# Epoch 12/20
# 24/24 [==============================] - 4s 158ms/step - loss: 94.1880 - accuracy: 0.4456 - val_loss: 94.0179 - val_accuracy: 0.4450
# Epoch 13/20
# 24/24 [==============================] - 4s 158ms/step - loss: 94.3730 - accuracy: 0.4430 - val_loss: 91.1703 - val_accuracy: 0.4503
# Epoch 14/20
# 24/24 [==============================] - 4s 159ms/step - loss: 94.1786 - accuracy: 0.4430 - val_loss: 95.8597 - val_accuracy: 0.4398
# Epoch 15/20
# 24/24 [==============================] - 4s 158ms/step - loss: 94.4170 - accuracy: 0.4364 - val_loss: 94.5512 - val_accuracy: 0.4607
# Epoch 16/20
# 24/24 [==============================] - 4s 161ms/step - loss: 94.4962 - accuracy: 0.4456 - val_loss: 96.4489 - val_accuracy: 0.4607
# Epoch 17/20
# 24/24 [==============================] - 4s 161ms/step - loss: 94.8181 - accuracy: 0.4600 - val_loss: 91.8796 - val_accuracy: 0.4188
# Epoch 18/20
# 24/24 [==============================] - 4s 158ms/step - loss: 94.6051 - accuracy: 0.4430 - val_loss: 92.7151 - val_accuracy: 0.4764
# Epoch 19/20
# 24/24 [==============================] - 4s 160ms/step - loss: 94.8597 - accuracy: 0.4482 - val_loss: 96.6371 - val_accuracy: 0.4398
# Epoch 20/20
# 24/24 [==============================] - 4s 169ms/step - loss: 94.7941 - accuracy: 0.4574 - val_loss: 96.8253 - val_accuracy: 0.2670

# %% [markdown]
# # Training non-aug

# %%
def create_model_comp(num_filters_1, num_filters_2, num_filters_3, dense_units_1, dense_units_2, dropout_rate, l1_reg, learning_rate):
    model = Sequential()
    model.add(Conv2D(num_filters_1, (3, 3), activation='relu', input_shape=(221, 1537, 1), kernel_regularizer=l1(l1_reg)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(num_filters_2, (3, 3), activation='relu', kernel_regularizer=l1(l1_reg)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(num_filters_3, (3, 3), activation='relu', kernel_regularizer=l1(l1_reg)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(dense_units_1, activation='relu', kernel_regularizer=l1(l1_reg)))
    model.add(Dropout(dropout_rate))
    model.add(Dense(dense_units_2, activation='relu', kernel_regularizer=l1(l1_reg)))
    model.add(Dropout(dropout_rate))
    model.add(Dense(4, activation='softmax'))
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

    return model

# %%
y_bin = label_binarize(y_train, classes=['angry', 'happy', 'sad', 'neutral',])
y_val_bin = label_binarize(y_val, classes=['angry', 'happy', 'sad', 'neutral',])

# %%
history72 = History()
model = create_model_comp(32, 32, 32, 256, 256, 0.2, 0.002, 0.0001)
model.fit(X_train, y_bin, epochs=80, batch_size=32, verbose=1, validation_data=(X_val, y_val_bin), callbacks=[history72])
# Out:
# Epoch 1/80
# 23/23 [==============================] - 12s 334ms/step - loss: 209.8221 - accuracy: 0.2986 - val_loss: 152.4367 - val_accuracy: 0.4481
# Epoch 2/80
# 23/23 [==============================] - 5s 217ms/step - loss: 118.9674 - accuracy: 0.3644 - val_loss: 88.6950 - val_accuracy: 0.4208
# Epoch 3/80
# 23/23 [==============================] - 5s 218ms/step - loss: 74.5317 - accuracy: 0.4151 - val_loss: 64.4985 - val_accuracy: 0.4208
# Epoch 4/80
# 23/23 [==============================] - 5s 215ms/step - loss: 58.5813 - accuracy: 0.4205 - val_loss: 53.1422 - val_accuracy: 0.4208
# Epoch 5/80
# 23/23 [==============================] - 5s 213ms/step - loss: 49.1885 - accuracy: 0.4151 - val_loss: 45.1755 - val_accuracy: 0.4208
# Epoch 6/80
# 23/23 [==============================] - 5s 213ms/step - loss: 42.0113 - accuracy: 0.4315 - val_loss: 38.7073 - val_accuracy: 0.4208
# Epoch 7/80
# 23/23 [==============================] - 5s 211ms/step - loss: 36.0626 - accuracy: 0.4466 - val_loss: 33.4153 - val_accuracy: 0.4208
# Epoch 8/80
# 23/23 [==============================] - 5s 212ms/step - loss: 31.1325 - accuracy: 0.4356 - val_loss: 28.8057 - val_accuracy: 0.4208
# Epoch 9/80
# 23/23 [==============================] - 5s 207ms/step - loss: 26.8857 - accuracy: 0.4384 - val_loss: 24.9517 - val_accuracy: 0.4208
# Epoch 10/80
# 23/23 [==============================] - 5s 207ms/step - loss: 23.4052 - accuracy: 0.4438 - val_loss: 21.7865 - val_accuracy: 0.4208
80
# 23/23 [==============================] - 5s 211ms/step - loss: 4.1717 - accuracy: 0.8753 - val_loss: 5.2611 - val_accuracy: 0.5082
# Epoch 73/80
# 23/23 [==============================] - 5s 211ms/step - loss: 4.0563 - accuracy: 0.8959 - val_loss: 5.3033 - val_accuracy: 0.5082
# Epoch 74/80
# 23/23 [==============================] - 5s 210ms/step - loss: 4.0330 - accuracy: 0.8959 - val_loss: 5.2198 - val_accuracy: 0.4590
# Epoch 75/80
# 23/23 [==============================] - 5s 210ms/step - loss: 3.9599 - accuracy: 0.9000 - val_loss: 5.1297 - val_accuracy: 0.4918
# Epoch 76/80
# 23/23 [==============================] - 5s 212ms/step - loss: 3.9812 - accuracy: 0.8822 - val_loss: 5.1687 - val_accuracy: 0.4536
# Epoch 77/80
# 23/23 [==============================] - 5s 211ms/step - loss: 3.9741 - accuracy: 0.8863 - val_loss: 5.1587 - val_accuracy: 0.4590
# Epoch 78/80
# 23/23 [==============================] - 5s 213ms/step - loss: 3.9287 - accuracy: 0.9027 - val_loss: 5.1652 - val_accuracy: 0.4754
# Epoch 79/80
# 23/23 [==============================] - 5s 210ms/step - loss: 3.8816 - accuracy: 0.9027 - val_loss: 5.0893 - val_accuracy: 0.4754
# Epoch 80/80
# 23/23 [==============================] - 5s 209ms/step - loss: 3.8285 - accuracy: 0.9247 - val_loss: 5.1786 - val_accuracy: 0.4590

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_arg = np.argmax(y_bin2, axis=1)

test_loss, test_acc = model.evaluate(X_test, y_bin2)

print('Test accuracy:', test_acc)

f1 = f1_score(y_arg, y_pred, average='weighted')
print("F1-score:", f1)

print(classification_report(y_arg, y_pred))
# Out:
# 10/10 [==============================] - 1s 105ms/step
# 10/10 [==============================] - 1s 49ms/step - loss: 5.5621 - accuracy: 0.4033
# Test accuracy: 0.4032786786556244
# F1-score: 0.3998778371596092
#               precision    recall  f1-score   support
#
#            0       0.32      0.49      0.39        69
#            1       0.31      0.26      0.28        57
#            2       0.23      0.16      0.19        51
#            3       0.57      0.52      0.54       128
#
#     accuracy                           0.40       305
#    macro avg       0.36      0.36      0.35       305
# weighted avg       0.41      0.40      0.40       305

# %%
plothist(history72)

# %%
history72727 = History()
model = create_model_comp(32, 32, 32, 256, 256, 0.2, 0.005, 0.0001)
model.fit(X_train, y_bin, epochs=80, batch_size=32, verbose=1, validation_data=(X_val, y_val_bin), callbacks=[history72727])
# Out:
# Epoch 1/80
# 23/23 [==============================] - 12s 335ms/step - loss: 519.6722 - accuracy: 0.3219 - val_loss: 373.2363 - val_accuracy: 0.4317
# Epoch 2/80
# 23/23 [==============================] - 5s 219ms/step - loss: 283.2050 - accuracy: 0.3137 - val_loss: 203.1422 - val_accuracy: 0.4317
# Epoch 3/80
# 23/23 [==============================] - 5s 220ms/step - loss: 166.9008 - accuracy: 0.3712 - val_loss: 141.4037 - val_accuracy: 0.4317
# Epoch 4/80
# 23/23 [==============================] - 5s 221ms/step - loss: 126.9872 - accuracy: 0.3301 - val_loss: 113.6236 - val_accuracy: 0.4317
# Epoch 5/80
# 23/23 [==============================] - 5s 217ms/step - loss: 104.0622 - accuracy: 0.3507 - val_loss: 94.7036 - val_accuracy: 0.4317
# Epoch 6/80
# 23/23 [==============================] - 5s 215ms/step - loss: 87.8344 - accuracy: 0.3877 - val_loss: 80.5097 - val_accuracy: 0.4317
# Epoch 7/80
80
# 23/23 [==============================] - 5s 215ms/step - loss: 8.7223 - accuracy: 0.4616 - val_loss: 8.6871 - val_accuracy: 0.4317
# Epoch 70/80
# 23/23 [==============================] - 5s 214ms/step - loss: 8.6623 - accuracy: 0.4616 - val_loss: 8.6456 - val_accuracy: 0.4317
# Epoch 71/80
# 23/23 [==============================] - 5s 215ms/step - loss: 8.6134 - accuracy: 0.4616 - val_loss: 8.5818 - val_accuracy: 0.4317
# Epoch 72/80
# 23/23 [==============================] - 5s 215ms/step - loss: 8.5714 - accuracy: 0.4616 - val_loss: 8.5449 - val_accuracy: 0.4317
# Epoch 73/80
# 23/23 [==============================] - 5s 216ms/step - loss: 8.5132 - accuracy: 0.4616 - val_loss: 8.4854 - val_accuracy: 0.4317
# Epoch 74/80
# 23/23 [==============================] - 5s 215ms/step - loss: 8.4561 - accuracy: 0.4616 - val_loss: 8.4357 - val_accuracy: 0.4317
# Epoch 75/80
# 23/23 [==============================] - 5s 215ms/step - loss: 8.4124 - accuracy: 0.4616 - val_loss: 8.3750 - val_accuracy: 0.4317
# Epoch 76/80
# 23/23 [==============================] - 5s 214ms/step - loss: 8.3401 - accuracy: 0.4616 - val_loss: 8.3206 - val_accuracy: 0.4317
# Epoch 77/80
# 23/23 [==============================] - 5s 215ms/step - loss: 8.3017 - accuracy: 0.4616 - val_loss: 8.2906 - val_accuracy: 0.4317
# Epoch 78/80
# 23/23 [==============================] - 5s 215ms/step - loss: 8.2703 - accuracy: 0.4616 - val_loss: 8.2588 - val_accuracy: 0.4317
# Epoch 79/80
# 23/23 [==============================] - 5s 214ms/step - loss: 8.2160 - accuracy: 0.4616 - val_loss: 8.2027 - val_accuracy: 0.4317
# Epoch 80/80
# 23/23 [==============================] - 5s 215ms/step - loss: 8.1596 - accuracy: 0.4616 - val_loss: 8.1428 - val_accuracy: 0.4317

# %% [markdown]
# # Architectures/Functions

# %%
def create_model1d(num_filters_1, dense_units, dropout_rate, l1_reg):
    model = Sequential()

    model.add(Conv2D(num_filters_1, (3, 3), activation='relu', input_shape=(221, 1537, 1), kernel_regularizer=l1(l1_reg)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(dense_units, activation='relu', kernel_regularizer=l1(l1_reg)))
    model.add(Dropout(dropout_rate))
    model.add(Dense(6, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
def create_model_complex(num_filters_1, num_filters_2, num_filters_3, dense_units_1, dense_units_2, dropout_rate, l1_reg):
    model = Sequential()
    model.add(Conv2D(num_filters_1, (3, 3), activation='relu', input_shape=(221, 1537, 1), kernel_regularizer=l1(l1_reg)))
    model.add(Dropout(dropout_rate))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(num_filters_2, (3, 3), activation='relu', kernel_regularizer=l1(l1_reg)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(num_filters_3, (3, 3), activation='relu', kernel_regularizer=l1(l1_reg)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(dense_units_1, activation='relu', kernel_regularizer=l1(l1_reg)))
    model.add(Dropout(dropout_rate))
    model.add(Dense(dense_units_2, activation='relu', kernel_regularizer=l1(l1_reg)))
    model.add(Dropout(dropout_rate))
    model.add(Dense(4, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    return model

# %%
def create_model_comp(num_filters_1, num_filters_2, num_filters_3, dense_units_1, dense_units_2, dropout_rate, l1_reg, learning_rate):
    model = Sequential()
    model.add(Conv2D(num_filters_1, (3, 3), activation='relu', input_shape=(221, 1537, 1), kernel_regularizer=l1(l1_reg)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(num_filters_2, (3, 3), activation='relu', kernel_regularizer=l1(l1_reg)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(num_filters_3, (3, 3), activation='relu', kernel_regularizer=l1(l1_reg)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(dense_units_1, activation='relu', kernel_regularizer=l1(l1_reg)))
    model.add(Dropout(dropout_rate))
    model.add(Dense(dense_units_2, activation='relu', kernel_regularizer=l1(l1_reg)))
    model.add(Dropout(dropout_rate))
    model.add(Dense(4, activation='softmax'))
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

    return model

# %%
history727 = History()
model = create_model_comp(16, 16, 16, 256, 256, 0.2, 0.001, 0.00005)
model.fit(specs_aug, y_bin_aug, epochs=50, batch_size=32, verbose=1, validation_data=(X_val, y_val_bin), callbacks=[history727])
# Out:
# Epoch 1/50
# 35/35 [==============================] - 9s 221ms/step - loss: 87.7716 - accuracy: 0.2349 - val_loss: 72.6917 - val_accuracy: 0.4031
# Epoch 2/50
# 35/35 [==============================] - 7s 201ms/step - loss: 65.2717 - accuracy: 0.2422 - val_loss: 57.3690 - val_accuracy: 0.3979
# Epoch 3/50
# 35/35 [==============================] - 7s 202ms/step - loss: 51.6499 - accuracy: 0.2523 - val_loss: 45.7118 - val_accuracy: 0.3979
# Epoch 43/50
# 35/35 [==============================] - 7s 202ms/step - loss: 7.1942 - accuracy: 0.2623 - val_loss: 7.1245 - val_accuracy: 0.1623
# Epoch 44/50
# 35/35 [==============================] - 7s 202ms/step - loss: 6.9816 - accuracy: 0.2642 - val_loss: 6.9006 - val_accuracy: 0.2251
# Epoch 45/50
# 35/35 [==============================] - 7s 202ms/step - loss: 6.7849 - accuracy: 0.2678 - val_loss: 6.7227 - val_accuracy: 0.2932
# Epoch 46/50
# 35/35 [==============================] - 7s 203ms/step - loss: 6.5898 - accuracy: 0.2751 - val_loss: 6.5102 - val_accuracy: 0.4398
# Epoch 47/50
# 35/35 [==============================] - 7s 203ms/step - loss: 6.3888 - accuracy: 0.3053 - val_loss: 6.3308 - val_accuracy: 0.4346
# Epoch 48/50
# 35/35 [==============================] - 7s 203ms/step - loss: 6.2209 - accuracy: 0.3135 - val_loss: 6.1743 - val_accuracy: 0.2880
# Epoch 49/50
# 35/35 [==============================] - 7s 204ms/step - loss: 6.0438 - accuracy: 0.2943 - val_loss: 6.0025 - val_accuracy: 0.3246
# Epoch 50/50
# 35/35 [==============================] - 7s 204ms/step - loss: 5.8708 - accuracy: 0.3346 - val_loss: 5.8285 - val_accuracy: 0.4660

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_arg = np.argmax(y_bin2, axis=1)

test_loss, test_acc = model.evaluate(X_test, y_bin2)

print('Test accuracy:', test_acc)

f1 = f1_score(y_arg, y_pred, average='weighted')
print("F1-score:", f1)

print(confusion_matrix(y_arg, y_pred))
# Out:
# 10/10 [==============================] - 1s 80ms/step
# 10/10 [==============================] - 0s 32ms/step - loss: 5.7877 - accuracy: 0.4245
# Test accuracy: 0.4245283007621765
# F1-score: 0.36517501383550605
# [[26  0  5 40  0  0]
#  [23  0  2 33  0  0]
#  [ 1  0 14 26  0  0]
#  [17  0 25 95  0  0]
#  [ 0  0  0  1  0  0]
#  [ 2  0  0  8  0  0]]

# %%
history6 = History()
model = create_model_complex(16, 16, 16, 256, 256, 0.2, 0.001)
model.fit(specs_aug, y_bin_aug, epochs=20, batch_size=32, verbose=1, validation_data=(X_val, y_val_bin), callbacks=[history6])
# Out:
# Epoch 1/20
# 35/35 [==============================] - 11s 240ms/step - loss: 50.0879 - accuracy: 0.2358 - val_loss: 27.3432 - val_accuracy: 0.3979
# Epoch 2/20
# 35/35 [==============================] - 7s 201ms/step - loss: 21.8866 - accuracy: 0.3789 - val_loss: 17.7538 - val_accuracy: 0.3455
# Epoch 3/20
# 35/35 [==============================] - 7s 201ms/step - loss: 15.0932 - accuracy: 0.4651 - val_loss: 13.0583 - val_accuracy: 0.3770
# Epoch 4/20
# 35/35 [==============================] - 7s 203ms/step - loss: 11.5652 - accuracy: 0.5431 - val_loss: 10.3916 - val_accuracy: 0.4817
# Epoch 5/20
# 35/35 [==============================] - 7s 203ms/step - loss: 9.4300 - accuracy: 0.5550 - val_loss: 9.0928 - val_accuracy: 0.3717
# Epoch 6/20
# 35/35 [==============================] - 7s 203ms/step - loss: 8.2801 - accuracy: 0.6000 - val_loss: 8.9243 - val_accuracy: 0.4974
# Epoch 7/20
# 35/35 [==============================] - 7s 207ms/step - loss: 7.8388 - accuracy: 0.6303 - val_loss: 7.5754 - val_accuracy: 0.4398
# Epoch 8/20
# 35/35 [==============================] - 7s 202ms/step - loss: 6.7953 - accuracy: 0.6651 - val_loss: 7.0694 - val_accuracy: 0.4188
# Epoch 9/20
# 35/35 [==============================] - 7s 202ms/step - loss: 6.2406 - accuracy: 0.7028 - val_loss: 6.7522 - val_accuracy: 0.3717
# Epoch 10/20
# 35/35 [==============================] - 7s 201ms/step - loss: 5.9506 - accuracy: 0.7376 - val_loss: 6.6974 - val_accuracy: 0.3927
# Epoch 11/20
# 35/35 [==============================] - 7s 203ms/step - loss: 5.6112 - accuracy: 0.7688 - val_loss: 6.6200 - val_accuracy: 0.4188
# Epoch 12/20
# 35/35 [==============================] - 7s 204ms/step - loss: 5.7127 - accuracy: 0.7697 - val_loss: 6.5860 - val_accuracy: 0.3822
# Epoch 13/20
# 35/35 [==============================] - 7s 205ms/step - loss: 5.3514 - accuracy: 0.8275 - val_loss: 6.5853 - val_accuracy: 0.3298
# Epoch 14/20
# 35/35 [==============================] - 7s 204ms/step - loss: 5.3504 - accuracy: 0.7991 - val_loss: 6.5501 - val_accuracy: 0.3089
# Epoch 15/20
# 35/35 [==============================] - 7s 205ms/step - loss: 5.3542 - accuracy: 0.8037 - val_loss: 6.3073 - val_accuracy: 0.4031
# Epoch 16/20
# 35/35 [==============================] - 7s 205ms/step - loss: 5.1553 - accuracy: 0.8257 - val_loss: 6.2921 - val_accuracy: 0.4084
# Epoch 17/20
# 35/35 [==============================] - 7s 205ms/step - loss: 5.8443 - accuracy: 0.8422 - val_loss: 7.5902 - val_accuracy: 0.3613
# Epoch 18/20
# 35/35 [==============================] - 7s 205ms/step - loss: 5.5349 - accuracy: 0.8752 - val_loss: 6.5863 - val_accuracy: 0.3927
# Epoch 19/20
# 35/35 [==============================] - 7s 205ms/step - loss: 4.9703 - accuracy: 0.8862 - val_loss: 6.3761 - val_accuracy: 0.3979
# Epoch 20/20
# 35/35 [==============================] - 7s 204ms/step - loss: 4.6627 - accuracy: 0.9055 - val_loss: 6.1167 - val_accuracy: 0.4817

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_arg = np.argmax(y_bin2, axis=1)

test_loss, test_acc = model.evaluate(X_test, y_bin2)

print('Test accuracy:', test_acc)

f1 = f1_score(y_arg, y_pred, average='weighted')
print("F1-score:", f1)

print(confusion_matrix(y_arg, y_pred))
# Out:
# 10/10 [==============================] - 0s 37ms/step
# 10/10 [==============================] - 0s 33ms/step - loss: 6.3153 - accuracy: 0.4340
# Test accuracy: 0.43396225571632385
# F1-score: 0.3944528605117428
# [[22 14  4 44  0  0]
#  [12  7  8 25  0  0]
#  [ 2  1 12 33  0  0]
#  [ 9 11 10 97  0  0]
#  [ 0  0  0  2  0  0]
#  [ 1  1  1  2  0  0]]

# %%
history7 = History()
model = create_model(16, 16, 256, 0.2, 0.002)
model.fit(specs_aug, y_bin_aug, epochs=20, batch_size=32, verbose=1, validation_data=(X_val, y_val_bin), callbacks=[history7])
history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Val loss', 'Val loss (complex)'], loc='upper right')
plt.show()

plt.plot(history7.history['val_accuracy'])
plt.plot(history6.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Val accuracy', 'Val accuracy (complex)'], loc='upper right')
plt.show()

# %%
history727 = History()
model = create_model_comp(16, 16, 16, 256, 256, 0.2, 0.001, 0.0001)
model.fit(specs_aug, y_bin_aug, epochs=50, batch_size=32, verbose=1, validation_data=(X_val, y_val_bin), callbacks=[history727])
# Out:
# Epoch 1/50
# 29/29 [==============================] - 15s 176ms/step - loss: 86.3562 - accuracy: 0.2625 - val_loss: 60.9855 - val_accuracy: 0.2295
# Epoch 2/50
# 29/29 [==============================] - 3s 114ms/step - loss: 50.5028 - accuracy: 0.2963 - val_loss: 40.7745 - val_accuracy: 0.4372
# Epoch 3/50
# 29/29 [==============================] - 3s 114ms/step - loss: 35.7908 - accuracy: 0.3126 - val_loss: 32.7739 - val_accuracy: 0.1421
# Epoch 4/50
# 29/29 [==============================] - 3s 115ms/step - loss: 30.7764 - accuracy: 0.2865 - val_loss: 29.2209 - val_accuracy: 0.4372
# Epoch 5/50
# 29/29 [==============================] - 3s 115ms/step - loss: 28.1375 - accuracy: 0.3366 - val_loss: 26.9537 - val_accuracy: 0.1967
# Epoch 6/50
# 29/29 [==============================] - 3s 116ms/step - loss: 25.9827 - accuracy: 0.3301 - val_loss: 24.9659 - val_accuracy: 0.4372
# Epoch 7/50
# 29/29 [==============================] - 3s 116ms/step - loss: 24.1650 - accuracy: 0.3224 - val_loss: 23.2770 - val_accuracy: 0.4372
# Epoch 8/50
# 29/29 [==============================] - 3s 116ms/step - loss: 22.5771 - accuracy: 0.3290 - val_loss: 21.7888 - val_accuracy: 0.4372
# Epoch 9/50
# 29/29 [==============================] - 3s 117ms/step - loss: 21.2156 - accuracy: 0.3235 - val_loss: 20.5873 - val_accuracy: 0.1421
# Epoch 10/50
# 29/29 [==============================] - 3s 118ms/step - loss: 19.9962 - accuracy: 0.3312 - val_loss: 19.3425 - val_accuracy: 0.4372
# Epoch 11/50
# 29/29 [==============================] - 3s 118ms/step - loss: 18.8752 - accuracy: 0.3312 - val_loss: 18.2965 - val_accuracy: 0.4372
# Epoch 12/50
# 29/29 [==============================] - 3s 119ms/step - loss: 17.8693 - accuracy: 0.3126 - val_loss: 17.3959 - val_accuracy: 0.4372
# Epoch 13/50
# 29/29 [==============================] - 3s 120ms/step - loss: 17.0858 - accuracy: 0.3170 - val_loss: 16.5500 - val_accuracy: 0.4372
# Epoch 14/50
# 29/29 [==============================] - 4s 125ms/step - loss: 16.2324 - accuracy: 0.3170 - val_loss: 15.8140 - val_accuracy: 0.4372
# Epoch 15/50
# 29/29 [==============================] - 4s 121ms/step - loss: 15.5969 - accuracy: 0.3039 - val_loss: 15.2099 - val_accuracy: 0.4372
# Epoch 16/50
# 29/29 [==============================] - 3s 121ms/step - loss: 14.9373 - accuracy: 0.3540 - val_loss: 14.5538 - val_accuracy: 0.4372
# 29/29 [==============================] - 3s 119ms/step - loss: 6.9252 - accuracy: 0.3268 - val_loss: 6.7314 - val_accuracy: 0.4372
# Epoch 37/50
# 29/29 [==============================] - 3s 119ms/step - loss: 6.6846 - accuracy: 0.3344 - val_loss: 6.5186 - val_accuracy: 0.4372
# Epoch 38/50
# 29/29 [==============================] - 3s 119ms/step - loss: 6.4531 - accuracy: 0.3279 - val_loss: 6.3161 - val_accuracy: 0.4372
# Epoch 39/50
# 29/29 [==============================] - 3s 120ms/step - loss: 6.2311 - accuracy: 0.3519 - val_loss: 6.0975 - val_accuracy: 0.4208
# Epoch 40/50
# 29/29 [==============================] - 3s 120ms/step - loss: 5.9996 - accuracy: 0.3769 - val_loss: 5.8765 - val_accuracy: 0.4262
# Epoch 41/50
# 29/29 [==============================] - 3s 120ms/step - loss: 5.8009 - accuracy: 0.4063 - val_loss: 5.7442 - val_accuracy: 0.4645
# Epoch 42/50
# 29/29 [==============================] - 3s 120ms/step - loss: 5.6013 - accuracy: 0.4586 - val_loss: 5.5206 - val_accuracy: 0.4317
# Epoch 43/50
# 29/29 [==============================] - 3s 119ms/step - loss: 5.3923 - accuracy: 0.4673 - val_loss: 5.4176 - val_accuracy: 0.4317
# Epoch 44/50
# 29/29 [==============================] - 3s 119ms/step - loss: 5.2044 - accuracy: 0.5338 - val_loss: 5.2428 - val_accuracy: 0.4481
# Epoch 45/50
# 29/29 [==============================] - 3s 118ms/step - loss: 5.0122 - accuracy: 0.5479 - val_loss: 5.1372 - val_accuracy: 0.4481
# Epoch 46/50
# 29/29 [==============================] - 3s 119ms/step - loss: 4.8388 - accuracy: 0.6111 - val_loss: 5.0123 - val_accuracy: 0.4262
# Epoch 47/50
# 29/29 [==============================] - 3s 118ms/step - loss: 4.6825 - accuracy: 0.6166 - val_loss: 4.9091 - val_accuracy: 0.4481
# Epoch 48/50
# 29/29 [==============================] - 3s 119ms/step - loss: 4.5049 - accuracy: 0.6732 - val_loss: 4.8287 - val_accuracy: 0.4372
# Epoch 49/50
# 29/29 [==============================] - 3s 119ms/step - loss: 4.3395 - accuracy: 0.6972 - val_loss: 4.7324 - val_accuracy: 0.4153
# Epoch 50/50
# 29/29 [==============================] - 3s 119ms/step - loss: 4.1490 - accuracy: 0.7484 - val_loss: 4.7433 - val_accuracy: 0.4481

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_arg = np.argmax(y_bin2, axis=1)

test_loss, test_acc = model.evaluate(X_test, y_bin2)

print('Test accuracy:', test_acc)

f1 = f1_score(y_arg, y_pred, average='weighted')
print("F1-score:", f1)

print(classification_report(y_arg, y_pred))
# Out:
# 10/10 [==============================] - 1s 66ms/step
# 10/10 [==============================] - 0s 33ms/step - loss: 4.7768 - accuracy: 0.4262
# Test accuracy: 0.4262295067310333
# F1-score: 0.3813436565577871
#               precision    recall  f1-score   support
#
#            0       0.35      0.61      0.45        62
#            1       0.17      0.08      0.11        64
#            2       0.36      0.09      0.15        53
#            3       0.53      0.65      0.59       126
#
#     accuracy                           0.43       305
#    macro avg       0.35      0.36      0.32       305
# weighted avg       0.39      0.43      0.38       305
